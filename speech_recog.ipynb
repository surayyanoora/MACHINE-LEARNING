# %% [markdown]
# speech recognition:library in python serves the purpose of providing with a convenient an easy to use interface
# for performing speech recognition tsk within python programsspeech from audioto .
# it allows yuo to translate various audios such as microphone input ,audi files or audio streams
# translate spoken anguage to text

# %%
pip install SpeechRecognition
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting SpeechRecognition
# ...
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB 1.3 MB/s eta 0:00:26
#    ---------------------------------------- 0.1/32.8 MB 919.0 kB/s eta 0:00:36
#    ---------------------------------------- 0.1/32.8 MB 1.1 MB/s eta 0:00:31
#    ---------------------------------------- 0.2/32.8 MB 1.0 MB/s eta 0:00:33
#    ---------------------------------------- 0.2/32.8 MB 1.0 MB/s eta 0:00:32
#    ---------------------------------------- 0.3/32.8 MB 1.1 MB/s eta 0:00:31
#    ---------------------------------------- 0.4/32.8 MB 1.1 MB/s eta 0:00:29
#     --------------------------------------- 0.5/32.8 MB 1.2 MB/s eta 0:00:27
#     --------------------------------------- 0.5/32.8 MB 1.3 MB/s eta 0:00:26
#     --------------------------------------- 0.6/32.8 MB 1.2 MB/s eta 0:00:26
# ...

# %%
pip install pyaudio
# Out:
# ...
#    ---------------------------------------- 0.0/164.1 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/164.1 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/164.1 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/164.1 kB 330.3 kB/s eta 0:00:01
#    ------------------- ------------------- 81.9/164.1 kB 512.0 kB/s eta 0:00:01
#    -------------------------- ----------- 112.6/164.1 kB 595.3 kB/s eta 0:00:01
#    -------------------------------------- 164.1/164.1 kB 657.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## pyaudio to access mic

# %% [markdown]
# Audio playback :you can use pyaudio to play audio files or generate audio signals in real time.
# Audio  recording : pyaudio enables you to record audio from microphones or other input devices

# %%
import speech_recognition as sr

r= sr.Recognizer()

with sr.Microphone() as source:
    r.adjust_for_ambient_noise(source,duration=5)
    #r.energy_threshold()
    print("say anything :")
    audio = r.listen(source)
    try:
        text=r.recognize_google(audio)
        print(text)
    except:
        print("sorry,could not recognize")
# Out:
# say anything :
# how are you

# %%
import speech_recognition as sr
#filename = "speech-recognition.wav"
filename = "audio_speech.wav"
# initialize the recognizer
r = sr.Recognizer()

# open the file
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    try:
        text = r.recognize_google(audio_data)
        print(text)
    except:
        print("sorry,could not recognize")
# Out:
# good morning how are you
